# %%
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
import datetime as dt
import numpy as np

# %%
df = pd.read_csv('us_counties_covid19_daily.csv', parse_dates=['date'], dayfirst=True)

# %%
df.head()
# Out:
#         date     county       state     fips  cases  deaths
# 0 2020-01-21  Snohomish  Washington  53061.0      1       0
# 1 2020-01-22  Snohomish  Washington  53061.0      1       0
# 2 2020-01-23  Snohomish  Washington  53061.0      1       0
# 3 2020-01-24       Cook    Illinois  17031.0      1       0
# 4 2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df = df[['date', 'state','cases','deaths']]

# %%
df.head()
# Out:
#         date       state  cases  deaths
# 0 2020-01-21  Washington      1       0
# 1 2020-01-22  Washington      1       0
# 2 2020-01-23  Washington      1       0
# 3 2020-01-24    Illinois      1       0
# 4 2020-01-24  Washington      1       0

# %%
today = df[df.date == '2020-05-09']

# %%
today
# Out:
#              date    state  cases  deaths
# 127252 2020-05-09  Alabama     68       4
# 127253 2020-05-09  Alabama    216       5
# 127254 2020-05-09  Alabama     58       1
# 127255 2020-05-09  Alabama     45       1
# 127256 2020-05-09  Alabama     44       0
# ...           ...      ...    ...     ...
# 130237 2020-05-09  Wyoming      3       0
# 130238 2020-05-09  Wyoming     19       0
# 130239 2020-05-09  Wyoming     98       1
# 130240 2020-05-09  Wyoming      9       0
# 130241 2020-05-09  Wyoming      7       0
#
# [2990 rows x 4 columns]

# %%
max_confirmed_cases=today.sort_values(by="deaths",ascending=False)
max_confirmed_cases
# Out:
#              date     state   cases  deaths
# 128969 2020-05-09  New York  188663   19324
# 128968 2020-05-09  New York   38028    2388
# 127833 2020-05-09  Illinois   51674    2264
# 128499 2020-05-09  Michigan   17980    2084
# 128988 2020-05-09  New York   36461    1647
# ...           ...       ...     ...     ...
# 128677 2020-05-09  Missouri       3       0
# 128676 2020-05-09  Missouri      26       0
# 128673 2020-05-09  Missouri       4       0
# 128672 2020-05-09  Missouri       8       0
# 130241 2020-05-09   Wyoming       7       0
#
# [2990 rows x 4 columns]

# %%
top_states_confirmed=max_confirmed_cases[0:5]

sns.set(rc={'figure.figsize':(10,10)})
sns.barplot(x="state",y="deaths", data=top_states_confirmed, hue="state")
plt.show()

# %%
max_death_cases=today.sort_values(by="cases",ascending=False)
max_death_cases
# Out:
#              date       state   cases  deaths
# 128969 2020-05-09    New York  188663   19324
# 127833 2020-05-09    Illinois   51674    2264
# 128968 2020-05-09    New York   38028    2388
# 128988 2020-05-09    New York   36461    1647
# 127440 2020-05-09  California   31197    1512
# ...           ...         ...     ...     ...
# 129308 2020-05-09      Oregon       1       0
# 129322 2020-05-09      Oregon       1       0
# 128750 2020-05-09    Missouri       1       0
# 128268 2020-05-09    Kentucky       1       0
# 128875 2020-05-09      Nevada       0       5
#
# [2990 rows x 4 columns]

# %%
top_states_death=max_death_cases[0:5]

sns.set(rc={'figure.figsize':(10,10)})
sns.barplot(x="state",y="deaths",data=top_states_death,hue="state")
plt.show()

# %%
newY = df[df.state == 'New York']

# %%
newY
# Out:
#              date     state  cases  deaths
# 416    2020-03-01  New York      1       0
# 448    2020-03-02  New York      1       0
# 482    2020-03-03  New York      2       0
# 518    2020-03-04  New York      2       0
# 519    2020-03-04  New York      9       0
# ...           ...       ...    ...     ...
# 571991 2020-09-26  New York    296      14
# 571992 2020-09-26  New York    316       3
# 571993 2020-09-26  New York  38050    1456
# 571994 2020-09-26  New York    136       5
# 571995 2020-09-26  New York     62       6
#
# [11240 rows x 4 columns]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="deaths",data = newY, color="r")
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="cases",data = newY, color="b")
plt.show()

# %%
tex = df[df.state == 'Texas']

tex
# Out:
#              date  state  cases  deaths
# 143    2020-02-12  Texas      1       0
# 154    2020-02-13  Texas      2       0
# 165    2020-02-14  Texas      2       0
# 176    2020-02-15  Texas      2       0
# 187    2020-02-16  Texas      2       0
# ...           ...    ...    ...     ...
# 572961 2020-09-26  Texas    525      23
# 572962 2020-09-26  Texas    224       5
# 572963 2020-09-26  Texas    314       6
# 572964 2020-09-26  Texas    333       6
# 572965 2020-09-26  Texas    367      16
#
# [42685 rows x 4 columns]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="deaths",data = tex, color="g")
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="cases",data = tex, color="y")
plt.show()
